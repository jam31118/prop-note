# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation

import numpy as np

# %%
fig, ax = plt.subplots()

ax.set_xlim(-3,3), ax.set_ylim(-1.2, 1.2)
x_arr = np.linspace(-3,3,100)
line, = ax.plot([],[])

f_args = (line,)

def update(frame_index, line):
    line.set_data(x_arr, np.sin(x_arr - frame_index * 0.1))
    return (line,)

ani = FuncAnimation(fig, update, frames=range(20), fargs=f_args, repeat=False, blit=True)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
from matplotlib.animation import ImageMagickWriter
ani.save("ani.gif", writer=ImageMagickWriter())
